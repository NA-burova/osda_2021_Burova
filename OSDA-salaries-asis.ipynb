# %%
import pandas as pd, numpy as np

# %%
data=pd.read_csv("adult.data", header=None)
data.columns=["age", "workclass", "fnlwgt", "education", "education-num",
"marital-status", "occupation", "relationship", "race", "sex", "capital-gain", "capital-loss", "hours-per-week", "native-country", "income"]
data
# Out:
#        age          workclass  fnlwgt   education  education-num  \
# 0       39          State-gov   77516   Bachelors             13
# 1       50   Self-emp-not-inc   83311   Bachelors             13
# 2       38            Private  215646     HS-grad              9
# 3       53            Private  234721        11th              7
# 4       28            Private  338409   Bachelors             13
# ...    ...                ...     ...         ...            ...
# 48837   39            Private  215419   Bachelors             13
# 48838   64                  ?  321403     HS-grad              9
# 48839   38            Private  374983   Bachelors             13
# 48840   44            Private   83891   Bachelors             13
# 48841   35       Self-emp-inc  182148   Bachelors             13
#
#             marital-status          occupation     relationship  \
# 0            Never-married        Adm-clerical    Not-in-family
# 1       Married-civ-spouse     Exec-managerial          Husband
# 2                 Divorced   Handlers-cleaners    Not-in-family
# 3       Married-civ-spouse   Handlers-cleaners          Husband
# 4       Married-civ-spouse      Prof-specialty             Wife
# ...                    ...                 ...              ...
# 48837             Divorced      Prof-specialty    Not-in-family
# 48838              Widowed                   ?   Other-relative
# 48839   Married-civ-spouse      Prof-specialty          Husband
# 48840             Divorced        Adm-clerical        Own-child
# 48841   Married-civ-spouse     Exec-managerial          Husband
#
#                       race      sex  capital-gain  capital-loss  \
# 0                    White     Male          2174             0
# 1                    White     Male             0             0
# 2                    White     Male             0             0
# 3                    Black     Male             0             0
# 4                    Black   Female             0             0
# ...                    ...      ...           ...           ...
# 48837                White   Female             0             0
# 48838                Black     Male             0             0
# 48839                White     Male             0             0
# 48840   Asian-Pac-Islander     Male          5455             0
# 48841                White     Male             0             0
#
#        hours-per-week  native-country   income
# 0                  40   United-States    <=50K
# 1                  13   United-States    <=50K
# 2                  40   United-States    <=50K
# 3                  40   United-States    <=50K
# 4                  40            Cuba    <=50K
# ...               ...             ...      ...
# 48837              36   United-States   <=50K.
# 48838              40   United-States   <=50K.
# 48839              50   United-States   <=50K.
# 48840              40   United-States   <=50K.
# 48841              60   United-States    >50K.
#
# [48842 rows x 15 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             48842 non-null  int64
#  1   workclass       48842 non-null  object
#  2   fnlwgt          48842 non-null  int64
#  3   education       48842 non-null  object
#  4   education-num   48842 non-null  int64
#  5   marital-status  48842 non-null  object
#  6   occupation      48842 non-null  object
#  7   relationship    48842 non-null  object
#  8   race            48842 non-null  object
#  9   sex             48842 non-null  object
#  10  capital-gain    48842 non-null  int64
#  11  capital-loss    48842 non-null  int64
#  12  hours-per-week  48842 non-null  int64
#  13  native-country  48842 non-null  object
#  14  income          48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %%
data = data.replace(" ?", np.NaN)
data.dropna(inplace=True)
data.index=[i for i in range(data.shape[0])]
data=data.replace(" <=50K.", "<=50K")
data=data.replace(" >50K.", ">50K")
data=data.replace(" <=50K", "<=50K")
data=data.replace(" >50K", ">50K")
data
# Out:
#        age          workclass  fnlwgt   education  education-num  \
# 0       39          State-gov   77516   Bachelors             13
# 1       50   Self-emp-not-inc   83311   Bachelors             13
# 2       38            Private  215646     HS-grad              9
# 3       53            Private  234721        11th              7
# 4       28            Private  338409   Bachelors             13
# ...    ...                ...     ...         ...            ...
# 45217   33            Private  245211   Bachelors             13
# 45218   39            Private  215419   Bachelors             13
# 45219   38            Private  374983   Bachelors             13
# 45220   44            Private   83891   Bachelors             13
# 45221   35       Self-emp-inc  182148   Bachelors             13
#
#             marital-status          occupation    relationship  \
# 0            Never-married        Adm-clerical   Not-in-family
# 1       Married-civ-spouse     Exec-managerial         Husband
# 2                 Divorced   Handlers-cleaners   Not-in-family
# 3       Married-civ-spouse   Handlers-cleaners         Husband
# 4       Married-civ-spouse      Prof-specialty            Wife
# ...                    ...                 ...             ...
# 45217        Never-married      Prof-specialty       Own-child
# 45218             Divorced      Prof-specialty   Not-in-family
# 45219   Married-civ-spouse      Prof-specialty         Husband
# 45220             Divorced        Adm-clerical       Own-child
# 45221   Married-civ-spouse     Exec-managerial         Husband
#
#                       race      sex  capital-gain  capital-loss  \
# 0                    White     Male          2174             0
# 1                    White     Male             0             0
# 2                    White     Male             0             0
# 3                    Black     Male             0             0
# 4                    Black   Female             0             0
# ...                    ...      ...           ...           ...
# 45217                White     Male             0             0
# 45218                White   Female             0             0
# 45219                White     Male             0             0
# 45220   Asian-Pac-Islander     Male          5455             0
# 45221                White     Male             0             0
#
#        hours-per-week  native-country income
# 0                  40   United-States  <=50K
# 1                  13   United-States  <=50K
# 2                  40   United-States  <=50K
# 3                  40   United-States  <=50K
# 4                  40            Cuba  <=50K
# ...               ...             ...    ...
# 45217              40   United-States  <=50K
# 45218              36   United-States  <=50K
# 45219              50   United-States  <=50K
# 45220              40   United-States  <=50K
# 45221              60   United-States   >50K
#
# [45222 rows x 15 columns]

# %%
[len(np.unique(data[i])) for i in data]
# Out:
# [74, 7, 26741, 16, 16, 7, 14, 6, 5, 2, 121, 97, 96, 41, 2]

# %%
def binarize(data):
    bind=pd.DataFrame()
    for i in data:
        if type(data[i].values[0])==str:
            if len(np.unique(data[i]))==2:
                bind[i]=np.zeros(data.shape[0])
                bind.loc[data[i]==np.unique(data[i])[1], [i]]=1
            else:
                for j in np.unique(data[i]):
                    bind[i+"_"+j]=np.zeros(data.shape[0])
    #                 bind.loc[data[i]==j, [i+"_"+j]]=1
    #             bind[i+'x']=np.zeros(data.shape[0])
    #             bind.loc[data[i]=='x', [i+'x']]=1
        else: bind[i]=data[i]
    return bind

# %%
beta=data.copy()
beta.loc[beta["income"]=="<=50K", ["income"]]=1
beta.loc[beta["income"]==">50K", ["income"]]=0
beta
# Out:
#        age          workclass  fnlwgt   education  education-num  \
# 0       39          State-gov   77516   Bachelors             13
# 1       50   Self-emp-not-inc   83311   Bachelors             13
# 2       38            Private  215646     HS-grad              9
# 3       53            Private  234721        11th              7
# 4       28            Private  338409   Bachelors             13
# ...    ...                ...     ...         ...            ...
# 45217   33            Private  245211   Bachelors             13
# 45218   39            Private  215419   Bachelors             13
# 45219   38            Private  374983   Bachelors             13
# 45220   44            Private   83891   Bachelors             13
# 45221   35       Self-emp-inc  182148   Bachelors             13
#
#             marital-status          occupation    relationship  \
# 0            Never-married        Adm-clerical   Not-in-family
# 1       Married-civ-spouse     Exec-managerial         Husband
# 2                 Divorced   Handlers-cleaners   Not-in-family
# 3       Married-civ-spouse   Handlers-cleaners         Husband
# 4       Married-civ-spouse      Prof-specialty            Wife
# ...                    ...                 ...             ...
# 45217        Never-married      Prof-specialty       Own-child
# 45218             Divorced      Prof-specialty   Not-in-family
# 45219   Married-civ-spouse      Prof-specialty         Husband
# 45220             Divorced        Adm-clerical       Own-child
# 45221   Married-civ-spouse     Exec-managerial         Husband
#
#                       race      sex  capital-gain  capital-loss  \
# 0                    White     Male          2174             0
# 1                    White     Male             0             0
# 2                    White     Male             0             0
# 3                    Black     Male             0             0
# 4                    Black   Female             0             0
# ...                    ...      ...           ...           ...
# 45217                White     Male             0             0
# 45218                White   Female             0             0
# 45219                White     Male             0             0
# 45220   Asian-Pac-Islander     Male          5455             0
# 45221                White     Male             0             0
#
#        hours-per-week  native-country income
# 0                  40   United-States      1
# 1                  13   United-States      1
# 2                  40   United-States      1
# 3                  40   United-States      1
# 4                  40            Cuba      1
# ...               ...             ...    ...
# 45217              40   United-States      1
# 45218              36   United-States      1
# 45219              50   United-States      1
# 45220              40   United-States      1
# 45221              60   United-States      0
#
# [45222 rows x 15 columns]

# %%
income=beta["income"]
income
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 45217    1
# 45218    1
# 45219    1
# 45220    1
# 45221    0
# Name: income, Length: 45222, dtype: object

# %%
beta=beta.drop(["income"], axis=1)

# %%
X_pos=beta.loc[income==1]
X_neg=beta.loc[income==0]
X_pos.index=[i for i in range(X_pos.shape[0])]
X_neg.index=[i for i in range(X_neg.shape[0])]
y_pos=income.loc[income==1]
y_neg=income.loc[income==0]
y_pos.index=[i for i in range(X_pos.shape[0])]
y_neg.index=[i for i in range(y_neg.shape[0])]
X_pos
# Out:
#        age          workclass  fnlwgt   education  education-num  \
# 0       39          State-gov   77516   Bachelors             13
# 1       50   Self-emp-not-inc   83311   Bachelors             13
# 2       38            Private  215646     HS-grad              9
# 3       53            Private  234721        11th              7
# 4       28            Private  338409   Bachelors             13
# ...    ...                ...     ...         ...            ...
# 34009   48          Local-gov  349230     Masters             14
# 34010   33            Private  245211   Bachelors             13
# 34011   39            Private  215419   Bachelors             13
# 34012   38            Private  374983   Bachelors             13
# 34013   44            Private   83891   Bachelors             13
#
#             marital-status          occupation    relationship  \
# 0            Never-married        Adm-clerical   Not-in-family
# 1       Married-civ-spouse     Exec-managerial         Husband
# 2                 Divorced   Handlers-cleaners   Not-in-family
# 3       Married-civ-spouse   Handlers-cleaners         Husband
# 4       Married-civ-spouse      Prof-specialty            Wife
# ...                    ...                 ...             ...
# 34009             Divorced       Other-service   Not-in-family
# 34010        Never-married      Prof-specialty       Own-child
# 34011             Divorced      Prof-specialty   Not-in-family
# 34012   Married-civ-spouse      Prof-specialty         Husband
# 34013             Divorced        Adm-clerical       Own-child
#
#                       race      sex  capital-gain  capital-loss  \
# 0                    White     Male          2174             0
# 1                    White     Male             0             0
# 2                    White     Male             0             0
# 3                    Black     Male             0             0
# 4                    Black   Female             0             0
# ...                    ...      ...           ...           ...
# 34009                White     Male             0             0
# 34010                White     Male             0             0
# 34011                White   Female             0             0
# 34012                White     Male             0             0
# 34013   Asian-Pac-Islander     Male          5455             0
#
#        hours-per-week  native-country
# 0                  40   United-States
# 1                  13   United-States
# 2                  40   United-States
# 3                  40   United-States
# 4                  40            Cuba
# ...               ...             ...
# 34009              40   United-States
# 34010              40   United-States
# 34011              36   United-States
# 34012              50   United-States
# 34013              40   United-States
#
# [34014 rows x 14 columns]

# %%
from sklearn.model_selection import train_test_split
test_size=1/20
_, X_pos, _, y_pos=train_test_split(X_pos, y_pos, test_size=test_size)
_, X_neg, _, y_neg=train_test_split(X_neg, y_neg, test_size=test_size)

# %%
X_pos
# Out:
#        age          workclass  fnlwgt      education  education-num  \
# 25708   35   Self-emp-not-inc  107662        HS-grad              9
# 30795   18            Private  131825           11th              7
# 30164   53            Private  308082      Preschool              1
# 27135   17            Private  197186           10th              6
# 20592   43            Private  282069   Some-college             10
# ...    ...                ...     ...            ...            ...
# 10146   27            Private  212622        Masters             14
# 806     51            Private  284329        HS-grad              9
# 27121   23            Private  154785   Some-college             10
# 32012   41            Private  169473        HS-grad              9
# 23029   60            Private  209844   Some-college             10
#
#        marital-status          occupation     relationship  \
# 25708   Never-married       Other-service        Unmarried
# 30795   Never-married   Machine-op-inspct        Own-child
# 30164   Never-married       Other-service    Not-in-family
# 27135   Never-married               Sales        Own-child
# 20592        Divorced        Craft-repair        Unmarried
# ...               ...                 ...              ...
# 10146   Never-married     Exec-managerial        Own-child
# 806           Widowed    Transport-moving        Unmarried
# 27121   Never-married        Adm-clerical   Other-relative
# 32012        Divorced       Other-service    Not-in-family
# 23029        Divorced        Adm-clerical   Other-relative
#
#                       race      sex  capital-gain  capital-loss  \
# 25708                White   Female             0             0
# 30795                White     Male             0             0
# 30164                White   Female             0             0
# 27135                White   Female             0             0
# 20592                White     Male             0             0
# ...                    ...      ...           ...           ...
# 10146                White   Female             0             0
# 806                  White     Male             0             0
# 27121   Asian-Pac-Islander   Female             0             0
# 32012                White   Female             0             0
# 23029                White   Female             0             0
#
#        hours-per-week  native-country
# 25708               5          Canada
# 30795              21   United-States
# 30164              15     El-Salvador
# 27135              24   United-States
# 20592              42   United-States
# ...               ...             ...
# 10146              40   United-States
# 806                40   United-States
# 27121              40   United-States
# 32012              30   United-States
# 23029              40   United-States
#
# [1701 rows x 14 columns]

# %%
X_pos.index=[i for i in range(X_pos.shape[0])]
X_neg.index=[i for i in range(X_neg.shape[0])]
y_pos.index=[i for i in range(X_pos.shape[0])]
y_neg.index=[i for i in range(y_neg.shape[0])]
X_pos
# Out:
#       age          workclass  fnlwgt      education  education-num  \
# 0      35   Self-emp-not-inc  107662        HS-grad              9
# 1      18            Private  131825           11th              7
# 2      53            Private  308082      Preschool              1
# 3      17            Private  197186           10th              6
# 4      43            Private  282069   Some-college             10
# ...   ...                ...     ...            ...            ...
# 1696   27            Private  212622        Masters             14
# 1697   51            Private  284329        HS-grad              9
# 1698   23            Private  154785   Some-college             10
# 1699   41            Private  169473        HS-grad              9
# 1700   60            Private  209844   Some-college             10
#
#       marital-status          occupation     relationship  \
# 0      Never-married       Other-service        Unmarried
# 1      Never-married   Machine-op-inspct        Own-child
# 2      Never-married       Other-service    Not-in-family
# 3      Never-married               Sales        Own-child
# 4           Divorced        Craft-repair        Unmarried
# ...              ...                 ...              ...
# 1696   Never-married     Exec-managerial        Own-child
# 1697         Widowed    Transport-moving        Unmarried
# 1698   Never-married        Adm-clerical   Other-relative
# 1699        Divorced       Other-service    Not-in-family
# 1700        Divorced        Adm-clerical   Other-relative
#
#                      race      sex  capital-gain  capital-loss  \
# 0                   White   Female             0             0
# 1                   White     Male             0             0
# 2                   White   Female             0             0
# 3                   White   Female             0             0
# 4                   White     Male             0             0
# ...                   ...      ...           ...           ...
# 1696                White   Female             0             0
# 1697                White     Male             0             0
# 1698   Asian-Pac-Islander   Female             0             0
# 1699                White   Female             0             0
# 1700                White   Female             0             0
#
#       hours-per-week  native-country
# 0                  5          Canada
# 1                 21   United-States
# 2                 15     El-Salvador
# 3                 24   United-States
# 4                 42   United-States
# ...              ...             ...
# 1696              40   United-States
# 1697              40   United-States
# 1698              40   United-States
# 1699              30   United-States
# 1700              40   United-States
#
# [1701 rows x 14 columns]

# %%
from sklearn.model_selection import train_test_split
test_size=0.01
X_train_pos, X_test_pos, y_train_pos,  y_test_pos = train_test_split(X_pos, y_pos, test_size=test_size)
X_train_neg, X_test_neg, y_train_neg, y_test_neg = train_test_split(X_neg, y_neg, test_size=test_size)

# %%
X_test_pos
# Out:
#       age          workclass  fnlwgt      education  education-num  \
# 828    29            Private   26451        HS-grad              9
# 1575   42            Private  152889           10th              6
# 1248   30            Private   97723        HS-grad              9
# 1433   31            Private  145377      Bachelors             13
# 784    49            Private   75673        HS-grad              9
# 857    30            Private  119522           10th              6
# 1396   37            Private  236990   Some-college             10
# 1648   24            Private  275421      Assoc-voc             11
# 1333   27            Private   50316   Some-college             10
# 409    35            Private  148334   Some-college             10
# 1081   23          Local-gov  247731        HS-grad              9
# 447    27            Private  247711        HS-grad              9
# 975    43   Self-emp-not-inc  150528        HS-grad              9
# 909    20            Private  258430   Some-college             10
# 924    29            Private  354558        HS-grad              9
# 352    47            Private  186311      Bachelors             13
# 1017   39            Private  261504           12th              8
# 497    80            Private  249983        7th-8th              4
#
#            marital-status          occupation    relationship  \
# 828    Married-civ-spouse   Handlers-cleaners         Husband
# 1575   Married-civ-spouse        Craft-repair         Husband
# 1248        Never-married   Machine-op-inspct       Own-child
# 1433   Married-civ-spouse               Sales         Husband
# 784         Never-married        Adm-clerical       Own-child
# 857    Married-civ-spouse        Craft-repair         Husband
# 1396   Married-civ-spouse   Machine-op-inspct         Husband
# 1648        Never-married   Machine-op-inspct       Own-child
# 1333        Never-married     Exec-managerial   Not-in-family
# 409         Never-married        Adm-clerical       Own-child
# 1081             Divorced        Adm-clerical       Own-child
# 447    Married-civ-spouse        Adm-clerical            Wife
# 975    Married-civ-spouse        Craft-repair         Husband
# 909         Never-married       Other-service       Own-child
# 924    Married-civ-spouse               Sales         Husband
# 352         Never-married     Exec-managerial   Not-in-family
# 1017             Divorced        Adm-clerical       Unmarried
# 497               Widowed       Other-service   Not-in-family
#
#                      race      sex  capital-gain  capital-loss  \
# 828    Amer-Indian-Eskimo     Male             0             0
# 1575                White     Male             0             0
# 1248                White     Male             0             0
# 1433                White     Male             0             0
# 784    Asian-Pac-Islander   Female             0             0
# 857                 White     Male             0             0
# 1396                White     Male          3464             0
# 1648                White   Female             0             0
# 1333                White     Male             0             0
# 409                 Black     Male             0             0
# 1081                White   Female             0             0
# 447                 White   Female             0             0
# 975                 White     Male             0             0
# 909                 White   Female             0             0
# 924                 White     Male             0             0
# 352                 White   Female             0             0
# 1017                White   Female             0             0
# 497                 White   Female             0             0
#
#       hours-per-week  native-country
# 828               40   United-States
# 1575              45   United-States
# 1248              45   United-States
# 1433              60   United-States
# 784               40   United-States
# 857               45   United-States
# 1396              40   United-States
# 1648              40   United-States
# 1333              40   United-States
# 409               40   United-States
# 1081              40            Cuba
# 447               40   United-States
# 975               30   United-States
# 909               19   United-States
# 924               60   United-States
# 352               50   United-States
# 1017              40   United-States
# 497               24   United-States

# %%
def inter_bin(x, y):
    return x*y

# %%
def inter_cat(x,y):
    return [x, y]

# %%
def inter_num(x, y):
    return [np.min([x, y]), np.max([x, y])]

# %%
def inter(x,y, meta):
    res=[]
    for i in range(len(x)):
        if meta[i]=="bin":
            res.append(inter_bin(x[i], y[i]))
        elif meta[i]=="cat":
            res.append(inter_cat(x[i], y[i]))
        elif meta[i]=="num":
            res.append(inter_num(x[i], y[i]))
        else:
            raise Exception(str("Unknown metadata passed: "+meta[i]+" please use one of the following: bin, num, cat"))
    return np.array(res, dtype=object)

# %%
def isin(x, y, meta):
#     z=inter(x, y, meta)
#     print(z)
    res=True
    for i in range(len(x)):
        if meta[i]=="bin":
            res*=(y[i]>=x[i])
        elif meta[i]=="cat":
            res*=(y[i] in x[i])
        elif meta[i]=="num":
            res*=(x[i][0]<=y[i]<=x[i][1])
        else:
            raise Exception(str("Unknown metadata passed: "+meta[i]+" please use one of the following: bin, num, cat"))
        if not res: return res
    return res

# %%
def support(x, cl, meta):
    return np.mean([isin(x, i, meta) for i in cl])

# %%
def conf(x, y, meta, numdiff=0):
#     print(x, y)
    res=[]
    for i in range(len(x)):
        if meta[i]=="bin" or meta[i]=="cat":
            res.append(x[i]==y[i])
        elif meta[i]=="num":
            res.append(int(abs(x[i]-y[i])<=numdiff))
        else:
            raise Exception(str("Unknown metadata passed: "+meta[i]+" please use one of the following: bin, num, cat"))
    return np.mean(res)

# %%
beta.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country'],
#       dtype='object')

# %%
met=['num', 'cat', 'num', 'cat', 'num',
    'cat', 'cat', 'cat', 'cat', 'cat',
    'num', 'num', 'num', 'cat']
met, len(met)
# Out:
# (['num',
#   'cat',
#   'num',
#   'cat',
#   'num',
#   'cat',
#   'cat',
#   'cat',
#   'cat',
#   'cat',
#   'num',
#   'num',
#   'num',
#   'cat'],
#  14)

# %%
def classify(x, X_pos, X_neg, min_conf, minsup, aconf, meta, numdif=0, maxcont=0):
    cont_pos=0
    sup_pos=0
    npos=0
    minsuppos=np.inf
    maxsuppos=0
    mincontpos=np.inf
    maxcontpos=0
    
    for i in X_pos:
        z=inter(i, x, meta)
        c=conf(i, x, meta, numdif)
#         print(c)
        if c>=min_conf:
            print("c")
            return True
           
        if c>=aconf:
#             print(c)
            sup=support(z, X_pos, meta)
            if sup>=minsup:
                return 1
            cont=support(z, X_neg, meta)
#             if cont<=maxcont:
#                 return 1
            cont_pos+=cont
            sup_pos+=sup
            npos+=1
            minsuppos=min(minsuppos, sup)
            maxsuppos=max(maxsuppos, sup)
            mincontpos=min(mincontpos, cont)
            maxcontpos=max(maxcontpos, cont)
    #     print("+")
    
    cont_neg=0
    sup_neg=0
    nneg=0
    minsupneg=np.inf
    maxsupneg=0
    mincontneg=np.inf
    maxcontneg=0
    
    for i in X_neg:
        z=inter(i, x, meta)
        c=conf(i, x, meta, numdif)
        if c>=min_conf:
            return False
        
        if c>=aconf:
#             print(c)
            sup=support(z, X_neg, meta)
            if sup>=minsup:
                return 0
            cont=support(z, X_pos, meta)
#             if cont<=maxcont:
#                 return 0
            cont_neg+=cont
            sup_neg+=sup
            nneg+=1
            minsupneg=min(minsupneg, sup)
            maxsupneg=max(maxsupneg, sup)
            mincontneg=min(mincontneg, cont)
            maxcontneg=max(maxcontneg, cont)      
#     print("-")
    
    
#     cont_pos/=npos
#     sup_pos/=npos
#     cont_neg/=nneg
#     sup_neg/=nneg
#     print(cont_pos,sup_pos, cont_neg,sup_neg)
#     print(minsupneg,
#             maxsupneg,
#             mincontneg,
#             maxcontneg,"\n" ,minsuppos,
#             maxsuppos,
#             mincontpos,
#             maxcontpos)
#     print(cont_pos,sup_pos, cont_neg,sup_neg)
    if sup_pos!=0 and sup_neg!=0:
        return int(cont_pos/sup_pos<cont_neg/sup_neg)
    elif sup_pos==0 or sup_neg==0 and not sup_pos==sup_neg:
        return int(sup_pos/X_pos.shape[0]>sup_neg/X_neg.shape[0])
    else: return int(cont_pos/X_pos.shape[0]<cont_neg/X_neg.shape[0])
#     return int(maxcontpos<maxcontneg)
#     return int(maxsuppos>maxsupneg)

# %%
# %time classify(X_test_pos.loc[X_test_pos.index[1]].values, X_train_pos.values, X_train_neg.values, 0.9, 0.9, 0.5, met, 0)
# Out:
# Wall time: 21.2 s
# 1

# %%
# %time classify(X_test_neg.loc[X_test_neg.index[1]].values, X_train_pos.values, X_train_neg.values, 0.9, 0.9, 0.5, met)
# Out:
# Wall time: 38 s
# 0

# %%
# %time y=np.array([classify(X_test_pos.loc[i].values, X_train_pos.values, X_train_neg.values, 0.9, 0.9, 0.5, met) for i in X_test_pos.index])
# Out:
# c

# %%
# %time yn=np.array([classify(X_test_neg.loc[i].values, X_train_pos.values, X_train_neg.values, 0.9, 0.9, 0.5, met) for i in X_test_neg.index])

# %%
def metrics(y, yn, y_true, yn_true):
    m=dict()
    FN=sum(y^y_true)
    FP=sum(yn^yn_true)
    TP=len(y_true)-FN
    TN=len(yn_true)-FP
    m["FN"]=FN
    m["FP"]=FP
    m["TP"]=TP
    m["TN"]=TN
    m["A"]=(TP+TN)/(FP+FN+TP+TN)
    m["TPR"]=TP/(TP+FN)
    m["TNR"]=TN/(TN+FP)
    m["NPV"]=TN/(TN+FN)
    m["PPV"]=TP/(TP+FP)
    m["FPR"]=FP/(FP+TN)
    m["FDR"]=FP/(FP+TP)
    m["P"]=1/2*(TP/(TP+FP)+TN/(TN+FN))
    m["R"]=1/2*(TP/(TP+FN)+TN/(TN+FP))
    return m

# %% [markdown]
# True Positive
# True Negative
# False Positive
# False Negative
# True Positive Rate
# True Negative Rate
# Negative Predictive Value
# False Positive Rate
# False Discovery Rate
# Accuracy
# Precision
# Recall

# %%
metrics(y, yn, np.array(y_test_pos, dtype=int), np.array(y_test_neg,  dtype=int))

# %%
from sklearn.model_selection import KFold
kf = KFold(n_splits=10, shuffle=True)

# %%
# %%time
a=0
# X_pos=beta.loc[win==1]
# X_neg=beta.loc[win==0]
# X_pos.index=[i for i in range(X_pos.shape[0])]
# X_neg.index=[i for i in range(X_neg.shape[0])]
# y_pos=win.loc[win==1]
# y_neg=win.loc[win==0]
# y_pos.index=[i for i in range(X_pos.shape[0])]
# y_neg.index=[i for i in range(y_neg.shape[0])]
l=[i for i in kf.split(X_pos)]
k=[i for i in kf.split(X_neg)]
for i in range(10):

    X_train_pos=X_pos.loc[l[i][0]]
    X_train_neg=X_neg.loc[k[i][0]]

    y_train_pos=y_pos.loc[l[i][0]]
    y_train_neg=y_neg.loc[k[i][0]]

    X_test_pos=X_pos.loc[l[i][1]]
    X_test_neg=X_neg.loc[k[i][1]]

    y_test_pos=y_pos.loc[l[i][1]]
    y_test_neg=y_neg.loc[k[i][1]]
    
    y=np.array([classify(X_test_pos.loc[i].values, X_train_pos.values, X_train_neg.values, 0.9, 0.9, 0.5, met) for i in X_test_pos.index])
    yn=np.array([classify(X_test_neg.loc[i].values, X_train_pos.values, X_train_neg.values, 0.9, 0.9, 0.5, met) for i in X_test_neg.index])
    a+=metrics(y, yn, np.array(y_test_pos, dtype=int), np.array(y_test_neg,  dtype=int))["A"]
    print(a)
a/10
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# <timed exec> in <listcomp>(.0)
#
# <ipython-input-83-fab70dad47b8> in classify(x, X_pos, X_neg, min_conf, minsup, aconf, meta, numdif, maxcont)
#      18         if c>=aconf:
#      19 #             print(c)
# ---> 20             sup=support(z, X_pos, meta)
#      21             if sup>=minsup:
#      22                 return 1
#
# <ipython-input-54-111506188150> in support(x, cl, meta)
#       1 def support(x, cl, meta):
# ----> 2     return np.mean([isin(x, i, meta) for i in cl])
#
# <ipython-input-54-111506188150> in <listcomp>(.0)
#       1 def support(x, cl, meta):
# ----> 2     return np.mean([isin(x, i, meta) for i in cl])
#
# <ipython-input-53-c0b21d6ca2f8> in isin(x, y, meta)
#       9             res*=(y[i] in x[i])
#      10         elif meta[i]=="num":
# ---> 11             res*=(x[i][0]<=y[i]<=x[i][1])
#      12         else:
#      13             raise Exception(str("Unknown metadata passed: "+meta[i]+" please use one of the following: bin, num, cat"))
#
# KeyboardInterrupt:
